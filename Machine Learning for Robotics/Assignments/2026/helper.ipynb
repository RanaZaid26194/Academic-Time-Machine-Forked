# %%
# Logistic Regression Assignment Starter File
# Course: Machine Learning for Robotics
# Topic: Logistic Regression From Scratch
# Instructions: Fill in the function bodies only. Do NOT change function names or parameters.
# Allowed Libraries: numpy, matplotlib, pandas (for CSV), sklearn.datasets.make_blobs (for dataset generation)
# Forbidden: sklearn.linear_model, sklearn.metrics, tensorflow, keras, torch, scipy.optimize, any built-in optimizer

import numpy as np
import matplotlib.pyplot as plt

# %%
# ==============================
# Part 1: Dataset Helper (Optional)
# ==============================
from sklearn.datasets import make_blobs

def generate_dataset(samples=300, features=2, centers=2, random_state=42):
    """
    Generates a 2D binary classification dataset for testing.

    Returns:
        X : numpy.ndarray of shape (samples, features)
        y : numpy.ndarray of shape (samples,)
    """
    X, y = make_blobs(n_samples=samples, n_features=features, centers=centers, random_state=random_state)
    return X, y

# %%
# ==============================
# Part 2: Function Definitions
# ==============================

# Sigmoid Function
def sigmoid(z):
    """
    Computes the sigmoid activation function.

    Parameters
    ----------
    z : scalar OR numpy.ndarray of any shape
        Linear combination of inputs and weights (w^T x + b)

    Returns
    -------
    output : same type and shape as z
        Sigmoid values (0 < output < 1)
    """
    pass

# Compute Cost (Binary Cross-Entropy)
def compute_cost(X, y, w, b):
    """
    Computes average Binary Cross-Entropy loss.

    Parameters
    ----------
    X : numpy.ndarray of shape (m, n)
    y : numpy.ndarray of shape (m,)
    w : numpy.ndarray of shape (n,)
    b : float

    Returns
    -------
    cost : float
        Average loss across all samples
    """
    pass

# 3 Compute Gradients
def compute_gradients(X, y, w, b):
    """
    Computes gradients of loss w.r.t weights and bias.

    Parameters
    ----------
    X : numpy.ndarray of shape (m, n)
    y : numpy.ndarray of shape (m,)
    w : numpy.ndarray of shape (n,)
    b : float

    Returns
    -------
    dw : numpy.ndarray of shape (n,)
        Gradient of loss w.r.t weights
    db : float
        Gradient of loss w.r.t bias
    """
    pass

# Training Function (Gradient Descent)
def train(X, y, learning_rate, epochs):
    """
    Trains Logistic Regression using Gradient Descent.

    Parameters
    ----------
    X : numpy.ndarray of shape (m, n)
    y : numpy.ndarray of shape (m,)
    learning_rate : float
    epochs : int

    Returns
    -------
    w : numpy.ndarray of shape (n,)
        Trained weight vector
    b : float
        Trained bias
    losses : list
        Loss value per epoch
    """
    pass

# Prediction Function
def predict(X, w, b):
    """
    Makes binary predictions using trained parameters.

    Parameters
    ----------
    X : numpy.ndarray of shape (m, n)
    w : numpy.ndarray of shape (n,)
    b : float

    Returns
    -------
    y_pred : numpy.ndarray of shape (m,)
        Binary predictions: 1 if probability >= 0.5 else 0
    """
    pass

# 6 Accuracy Helper
def compute_accuracy(y_true, y_pred):
    """
    Computes prediction accuracy manually.

    Parameters
    ----------
    y_true : numpy.ndarray of shape (m,)
    y_pred : numpy.ndarray of shape (m,)

    Returns
    -------
    accuracy : float
        Percentage of correct predictions
    """
    pass

# %%
# ==============================
# Example Usage (Students Can Use)
# ==============================
if __name__ == "__main__":
    # Generate dataset
    X, y = generate_dataset()
    plot_dataset(X, y)

    # Initialize parameters
    n_features = X.shape[1]
    w = np.random.randn(n_features)
    b = 0.0
    learning_rate = 0.01
    epochs = 1000

    # Students will call train() here
    # w, b, losses = train(X, y, learning_rate, epochs)
    # y_pred = predict(X, w, b)
    # accuracy = compute_accuracy(y, y_pred)
